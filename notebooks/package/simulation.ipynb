# %%
#default_exp simulation

# %%
#export
from combinatorial_gwas.genotype import load_genetic_file
from combinatorial_gwas.phenotypes import get_phenotype, read_csv_compressed
from combinatorial_gwas.data_catalog import get_parameters, get_catalog
import pandas as pd
from dataclasses import dataclass
from functools import partial, lru_cache
from collections import defaultdict
from fastcore.utils import partialler
import operator
from itertools import product, chain
import numpy as np
#import apricot
from sklearn import preprocessing
from typing import List
from tqdm.auto import tqdm

# %%
from combinatorial_gwas.high_level import chromosome_datasource, snp_filter

# %%
#export
@dataclass
class SNPInfoUnit:
    negation: str
    snp_id: str
    geno: str

# %%
#export
@dataclass
class SimulatedPheno:
    snps: SNPInfoUnit
    op: str
    query: str
    pheno_col: np.array
    case_count: int
    control_count: int

# %%
#export
def get_chrom_to_variants_dict(pairs_df):
    snp_set = set(pairs_df["snp1"].tolist() + pairs_df["snp2"].tolist())
    chrom_to_variants_dict = defaultdict(list)
    for snp_id in snp_set:
        chrom = int(snp_id.split(":")[0])
        chrom_to_variants_dict[chrom].append(snp_id)
    return chrom_to_variants_dict

# %%
#export
def get_simulation_geno_df(datasource, chrom_to_variants_dict, sample_ids=None):
    all_genos_all_chrom = []
    all_variants = []
    if sample_ids == None:
        sample_ids = datasource.samples
    for chrom, variants in chrom_to_variants_dict.items():
        genetic_file = datasource.genome_files[chrom]
        variant_arr = genetic_file.get_geno_each_sample(sample_ids = sample_ids, variant_ids = variants, one_hot_encoded=False)
        all_genos_all_chrom.append(variant_arr)
        all_variants += variants
    all_genos_all_chrom = np.hstack(all_genos_all_chrom)
    geno_df = pd.DataFrame(all_genos_all_chrom, columns = all_variants, index = sample_ids)
    return geno_df

# %%
#export
def get_genotype_dict(geno_df):
    geno_dict = {col: [SNPInfoUnit(*item) for item in product(["not", ""],[col], geno_df[col].unique())] for col in geno_df.columns}
    return geno_dict

# %%
#export
def get_two_snps_queries(geno_dict:dict, two_snp_rsid_list:List[str], geno_df):
    print(f"CREATING SIMULATED PHENOTYPES FOR SNP PAIRS {two_snp_rsid_list}")
    all_query_dict= {}
    two_snp_list = list(product(geno_dict[two_snp_rsid_list[0]], ["and", "or"], geno_dict[two_snp_rsid_list[1]])) + [[single_snp_query] for single_snp_query in geno_dict[two_snp_rsid_list[0]]] + [[single_snp_query] for single_snp_query in geno_dict[two_snp_rsid_list[1]]]
    snp_unit = "({negation} (`{snp_id}` == {geno}))"
    nan_snp_unit = "({negation} (`{snp_id}`.isna()))"
    
    for ele in two_snp_list:
        query = ""
        snps = []
        ops = []
        has_nan = None
        for part in ele:
            if isinstance(part, SNPInfoUnit):
                if np.isnan(part.geno):
                    unit = nan_snp_unit.format(**vars(part))
                    has_nan = True
                else:
                    unit = snp_unit.format(**vars(part))

                snps.append(part)
            else:
                unit = part
                ops.append(unit)
            query += " "
            query += unit
        if has_nan == True:
            continue
        pheno_col = geno_df.eval(query).astype(int)
        try: 
            case_count = pheno_col.value_counts()[1]
        except KeyError: 
            case_count = None
        try: 
            control_count = pheno_col.value_counts()[0] 
        except KeyError: 
            control_count = None
        simulated_pheno_obj = SimulatedPheno(query = query, snps = snps, op = ops, pheno_col = pheno_col, case_count = case_count, control_count = control_count)
        all_query_dict[query] = simulated_pheno_obj
    
    return all_query_dict

# %%
queries_dict
# Out:
# {' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=404360, control_count=83049),
#  ' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=274854, control_count=212555),
#  ' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=254551, control_count=232858),
#  ' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=456027, control_count=31382),
#  ' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=58904, control_count=428505),
#  ' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=188410, control_count=298999),
#  ' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=208713, control_count=278696),
#  ' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=7237, control_count=480172),
#  ' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=484476, control_count=2933),
#  ' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=477317, control_count=10092),
#  ' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=476659, control_count=10750),
#  ' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=487039, control_count=370),
#  ' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=466197, control_count=21212),
#  ' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=473356, control_count=14053),
#  ' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=474014, control_count=13395),
#  ' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=463634, control_count=23775),
#  ' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=280567, control_count=206842),
#  ' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=190749, control_count=296660),
#  ' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=176721, control_count=310688),
#  ' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=316442, control_count=170967),
#  ' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=40926, control_count=446483),
#  ' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=130744, control_count=356665),
#  ' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=144772, control_count=342637),
#  ' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=5051, control_count=482358),
#  ' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=466498, control_count=20911),
#  ' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=419651, control_count=67758),
#  ' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         1
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=412718, control_count=74691),
#  ' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=484853, control_count=2556),
#  ' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=342404, control_count=145005),
#  ' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         1
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=389251, control_count=98158),
#  ' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=396184, control_count=91225),
#  ' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 1.0)) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=324049, control_count=163360),
#  ' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=167865, control_count=319544),
#  ' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         0
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=113008, control_count=374401),
#  ' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=105786, control_count=381623),
#  ' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=188912, control_count=298497),
#  ' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=23992, control_count=463417),
#  ' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=78849, control_count=408560),
#  ' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         0
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=86071, control_count=401338),
#  ' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=2945, control_count=484464),
#  ' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=449564, control_count=37845),
#  ' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=367756, control_count=119653),
#  ' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=354017, control_count=133392),
#  ' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=482747, control_count=4662),
#  ' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=229702, control_count=257707),
#  ' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=311510, control_count=175899),
#  ' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=325249, control_count=162160),
#  ' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=196519, control_count=290890),
#  ' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=423924, control_count=63485),
#  ' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=288110, control_count=199299),
#  ' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=266780, control_count=220629),
#  ' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=478025, control_count=9384),
#  ' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=61689, control_count=425720),
#  ' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=197503, control_count=289906),
#  ' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=218833, control_count=268576),
#  ' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=7588, control_count=479821),
#  ' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=487261, control_count=148),
#  ' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=486410, control_count=999),
#  ' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=486779, control_count=630),
#  ' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=487390, control_count=19),
#  ' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=485761, control_count=1648),
#  ' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=486612, control_count=797),
#  ' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=486243, control_count=1166),
#  ' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='not', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' (not (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=485632, control_count=1777),
#  ' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=21212, control_count=466197),
#  ' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=14053, control_count=473356),
#  ' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=13395, control_count=474014),
#  ' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=23775, control_count=463634),
#  ' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=2933, control_count=484476),
#  ' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=10092, control_count=477317),
#  ' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=10750, control_count=476659),
#  ' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=370, control_count=487039),
#  ' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=428505, control_count=58904),
#  ' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=298999, control_count=188410),
#  ' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=278696, control_count=208713),
#  ' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=480172, control_count=7237),
#  ' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=83049, control_count=404360),
#  ' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=212555, control_count=274854),
#  ' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=232858, control_count=254551),
#  ' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=0.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 0.0)) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=31382, control_count=456027),
#  ' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=145005, control_count=342404),
#  ' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         0
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=98158, control_count=389251),
#  ' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=91225, control_count=396184),
#  ' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=163360, control_count=324049),
#  ' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=20911, control_count=466498),
#  ' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=67758, control_count=419651),
#  ' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         0
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=74691, control_count=412718),
#  ' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=2556, control_count=484853),
#  ' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=446483, control_count=40926),
#  ' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=356665, control_count=130744),
#  ' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=1.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 1.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         1
#  3         0
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=342637, control_count=144772),
# ...
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=175899, control_count=311510),
#  ' ( (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=162160, control_count=325249),
#  ' ( (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=290890, control_count=196519),
#  ' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=37845, control_count=449564),
#  ' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=119653, control_count=367756),
#  ' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=133392, control_count=354017),
#  ' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=4662, control_count=482747),
#  ' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=463417, control_count=23992),
#  ' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=408560, control_count=78849),
#  ' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         1
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=401338, control_count=86071),
#  ' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=484464, control_count=2945),
#  ' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=319544, control_count=167865),
#  ' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         1
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=374401, control_count=113008),
#  ' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=381623, control_count=105786),
#  ' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=2.0), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A` == 2.0)) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         1
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=298497, control_count=188912),
#  ' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=1648, control_count=485761),
#  ' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=797, control_count=486612),
#  ' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=1166, control_count=486243),
#  ' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A`.isna())) and (not (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=1777, control_count=485632),
#  ' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=148, control_count=487261),
#  ' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=999, control_count=486410),
#  ' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=630, control_count=486779),
#  ' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A`.isna())) and ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=19, control_count=487390),
#  ' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 2.0))', pheno_col=0         0
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    1
#  487406    1
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=425720, control_count=61689),
#  ' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 0.0))', pheno_col=0         1
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    1
#  487406    1
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=289906, control_count=197503),
#  ' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C` == 1.0))', pheno_col=0         1
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    1
#  487406    0
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=268576, control_count=218833),
#  ' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='not', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A`.isna())) or (not (`6:26118570_T_C`.isna()))', pheno_col=0         1
#  1         1
#  2         1
#  3         1
#  4         1
#           ..
#  487404    1
#  487405    0
#  487406    1
#  487407    1
#  487408    1
#  Length: 487409, dtype: int64, case_count=479821, control_count=7588),
#  ' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 2.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=2.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 2.0))', pheno_col=0         1
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    0
#  487406    0
#  487407    0
#  487408    1
#  Length: 487409, dtype: int64, case_count=63485, control_count=423924),
#  ' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 0.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=0.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 0.0))', pheno_col=0         0
#  1         1
#  2         0
#  3         0
#  4         0
#           ..
#  487404    1
#  487405    0
#  487406    0
#  487407    1
#  487408    0
#  Length: 487409, dtype: int64, case_count=199299, control_count=288110),
#  ' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 1.0))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=1.0)], op=[], query=' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C` == 1.0))', pheno_col=0         0
#  1         0
#  2         1
#  3         1
#  4         1
#           ..
#  487404    0
#  487405    0
#  487406    1
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=220629, control_count=266780),
#  ' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C`.isna()))': SimulatedPheno(snps=[SNPInfoUnit(negation='', snp_id='6:134911816_G_A', geno=nan), SNPInfoUnit(negation='', snp_id='6:26118570_T_C', geno=nan)], op=[], query=' ( (`6:134911816_G_A`.isna())) or ( (`6:26118570_T_C`.isna()))', pheno_col=0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  487404    0
#  487405    1
#  487406    0
#  487407    0
#  487408    0
#  Length: 487409, dtype: int64, case_count=9384, control_count=478025)}
